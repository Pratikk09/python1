# %% [markdown]
# ### API - Application programming interface

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Read the API key

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
api = os.getenv("API_KEY")

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":"microsoft","function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": api,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data =response.json()

# %%
data
# Out:
# {'bestMatches': [{'1. symbol': 'MSF0.FRK',
#    '2. name': 'MICROSOFT CORP. CDR',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.6429'},
#   {'1. symbol': 'MSFT',
#    '2. name': 'Microsoft Corporation',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '0.6154'},
#   {'1. symbol': '0QYP.LON',
#    '2. name': 'Microsoft Corporation',
#    '3. type': 'Equity',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'USD',
#    '9. matchScore': '0.6000'},
#   {'1. symbol': 'MSF.DEX',
#    '2. name': 'Microsoft Corporation',
#    '3. type': 'Equity',
#    '4. region': 'XETRA',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.6000'},
#   {'1. symbol': 'MSF.FRK',
#    '2. name': 'Microsoft Corporation',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '0.6000'},
#   {'1. symbol': 'MSFT34.SAO',
#    '2. name': 'Microsoft Corporation',
#    '3. type': 'Equity',
#    '4. region': 'Brazil/Sao Paolo',
#    '5. marketOpen': '10:00',
#    '6. marketClose': '17:30',
#    '7. timezone': 'UTC-03',
#    '8. currency': 'BRL',
#    '9. matchScore': '0.6000'},
#   {'1. symbol': 'MSFT.TRT',
#    '2. name': 'Microsoft CDR (CAD Hedged)',
#    '3. type': 'Equity',
#    '4. region': 'Toronto',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-05',
#    '8. currency': 'CAD',
#    '9. matchScore': '0.5143'}]}

# %%
data["bestMatches"]
# Out:
# [{'1. symbol': 'MSF0.FRK',
#   '2. name': 'MICROSOFT CORP. CDR',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.6429'},
#  {'1. symbol': 'MSFT',
#   '2. name': 'Microsoft Corporation',
#   '3. type': 'Equity',
#   '4. region': 'United States',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-04',
#   '8. currency': 'USD',
#   '9. matchScore': '0.6154'},
#  {'1. symbol': '0QYP.LON',
#   '2. name': 'Microsoft Corporation',
#   '3. type': 'Equity',
#   '4. region': 'United Kingdom',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '16:30',
#   '7. timezone': 'UTC+01',
#   '8. currency': 'USD',
#   '9. matchScore': '0.6000'},
#  {'1. symbol': 'MSF.DEX',
#   '2. name': 'Microsoft Corporation',
#   '3. type': 'Equity',
#   '4. region': 'XETRA',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.6000'},
#  {'1. symbol': 'MSF.FRK',
#   '2. name': 'Microsoft Corporation',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.6000'},
#  {'1. symbol': 'MSFT34.SAO',
#   '2. name': 'Microsoft Corporation',
#   '3. type': 'Equity',
#   '4. region': 'Brazil/Sao Paolo',
#   '5. marketOpen': '10:00',
#   '6. marketClose': '17:30',
#   '7. timezone': 'UTC-03',
#   '8. currency': 'BRL',
#   '9. matchScore': '0.6000'},
#  {'1. symbol': 'MSFT.TRT',
#   '2. name': 'Microsoft CDR (CAD Hedged)',
#   '3. type': 'Equity',
#   '4. region': 'Toronto',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-05',
#   '8. currency': 'CAD',
#   '9. matchScore': '0.5143'}]

# %% [markdown]
# ### Extracting only required detail

# %%
d ={}
for i in data["bestMatches"]:
  symbol = i["1. symbol"]
  d[symbol] = i["2. name"],i["4. region"],i["8. currency"]

# %%
d
# Out:
# {'MSF0.FRK': ('MICROSOFT CORP. CDR', 'Frankfurt', 'EUR'),
#  'MSFT': ('Microsoft Corporation', 'United States', 'USD'),
#  '0QYP.LON': ('Microsoft Corporation', 'United Kingdom', 'USD'),
#  'MSF.DEX': ('Microsoft Corporation', 'XETRA', 'EUR'),
#  'MSF.FRK': ('Microsoft Corporation', 'Frankfurt', 'EUR'),
#  'MSFT34.SAO': ('Microsoft Corporation', 'Brazil/Sao Paolo', 'BRL'),
#  'MSFT.TRT': ('Microsoft CDR (CAD Hedged)', 'Toronto', 'CAD')}

# %% [markdown]
# ### Get actual stock data for SBI

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"SBIN.BSE","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data2 = response.json()

# %%
data2
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SBIN.BSE',
#   '3. Last Refreshed': '2025-02-20',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-02-20': {'1. open': '727.8000',
#    '2. high': '731.8000',
#    '3. low': '723.0500',
#    '4. close': '729.6500',
#    '5. volume': '279931'},
#   '2025-02-19': {'1. open': '722.8000',
#    '2. high': '734.7500',
#    '3. low': '722.1000',
#    '4. close': '726.8000',
#    '5. volume': '174597'},
#   '2025-02-18': {'1. open': '727.9500',
#    '2. high': '727.9500',
#    '3. low': '717.4500',
#    '4. close': '725.7500',
#    '5. volume': '396321'},
#   '2025-02-17': {'1. open': '721.8500',
#    '2. high': '728.9500',
#    '3. low': '711.4000',
#    '4. close': '728.0500',
#    '5. volume': '751026'},
#   '2025-02-14': {'1. open': '729.4500',
#    '2. high': '732.7000',
#    '3. low': '716.1500',
#    '4. close': '722.0000',
#    '5. volume': '895669'},
#   '2025-02-13': {'1. open': '735.0000',
#    '2. high': '737.3000',
#    '3. low': '726.0500',
#    '4. close': '727.3000',
#    '5. volume': '605466'},
#   '2025-02-12': {'1. open': '732.9500',
#    '2. high': '738.3000',
#    '3. low': '717.2500',
#    '4. close': '733.2500',
#    '5. volume': '550605'},
#   '2025-02-11': {'1. open': '738.1500',
#    '2. high': '740.0000',
#    '3. low': '726.9000',
#    '4. close': '731.0000',
#    '5. volume': '826170'},
#   '2025-02-10': {'1. open': '740.5500',
#    '2. high': '744.0500',
#    '3. low': '733.6000',
#    '4. close': '736.8500',
#    '5. volume': '788061'},
#   '2025-02-07': {'1. open': '761.8000',
#    '2. high': '761.8000',
#    '3. low': '732.0500',
#    '4. close': '737.0500',
#    '5. volume': '1805880'},
#   '2025-02-06': {'1. open': '769.6500',
#    '2. high': '770.9500',
#    '3. low': '750.0000',
#    '4. close': '752.3500',
#    '5. volume': '1384322'},
#   '2025-02-05': {'1. open': '780.8000',
#    '2. high': '781.6000',
#    '3. low': '764.6500',
#    '4. close': '766.1000',
#    '5. volume': '654303'},
#   '2025-02-04': {'1. open': '766.3000',
#    '2. high': '780.8500',
#    '3. low': '766.0000',
#    '4. close': '779.2000',
#    '5. volume': '749753'},
#   '2025-02-03': {'1. open': '763.6500',
#    '2. high': '763.6500',
#    '3. low': '753.4500',
#    '4. close': '761.0000',
#    '5. volume': '427934'},
#   '2025-01-31': {'1. open': '765.0000',
#    '2. high': '777.7500',
#    '3. low': '759.3500',
#    '4. close': '773.1000',
#    '5. volume': '241965'},
#   '2025-01-30': {'1. open': '759.4000',
#    '2. high': '764.8500',
#    '3. low': '754.7000',
#    '4. close': '762.2000',
#    '5. volume': '618809'},
#   '2025-01-29': {'1. open': '752.5000',
#    '2. high': '760.2500',
#    '3. low': '749.8000',
#    '4. close': '758.7000',
#    '5. volume': '379821'},
#   '2025-01-28': {'1. open': '756.2000',
#    '2. high': '759.6000',
#    '3. low': '745.6500',
#    '4. close': '751.6500',
#    '5. volume': '794022'},
#   '2025-01-27': {'1. open': '740.0000',
#    '2. high': '755.3000',
#    '3. low': '736.0000',
#    '4. close': '749.2000',
#    '5. volume': '775011'},
#   '2025-01-24': {'1. open': '747.2000',
#    '2. high': '753.7500',
#    '3. low': '738.8500',
#    '4. close': '744.3500',
#    '5. volume': '458033'},
#   '2025-01-23': {'1. open': '751.9500',
#    '2. high': '755.8000',
#    '3. low': '743.3000',
#    '4. close': '745.9500',
#    '5. volume': '235130'},
#   '2025-01-22': {'1. open': '762.8500',
#    '2. high': '762.8500',
#    '3. low': '738.3000',
#    '4. close': '753.2500',
#    '5. volume': '237866'},
#   '2025-01-21': {'1. open': '784.9500',
#    '2. high': '785.3000',
#    '3. low': '756.2500',
#    '4. close': '759.0000',
#    '5. volume': '953600'},
#   '2025-01-20': {'1. open': '765.0500',
#    '2. high': '784.9500',
#    '3. low': '765.0500',
#    '4. close': '779.0500',
#    '5. volume': '559123'},
#   '2025-01-17': {'1. open': '766.9000',
#    '2. high': '767.8500',
#    '3. low': '759.4500',
#    '4. close': '764.1000',
#    '5. volume': '497950'},
#   '2025-01-16': {'1. open': '761.6500',
#    '2. high': '776.5500',
#    '3. low': '760.0500',
#    '4. close': '766.4000',
#    '5. volume': '511761'},
#   '2025-01-15': {'1. open': '753.7000',
#    '2. high': '758.8500',
#    '3. low': '750.3500',
#    '4. close': '754.0000',
#    '5. volume': '171791'},
#   '2025-01-14': {'1. open': '730.6000',
#    '2. high': '756.9000',
#    '3. low': '730.6000',
#    '4. close': '748.1000',
#    '5. volume': '687121'},
#   '2025-01-13': {'1. open': '742.9500',
#    '2. high': '743.8500',
#    '3. low': '722.5000',
#    '4. close': '729.6000',
#    '5. volume': '300275'},
#   '2025-01-10': {'1. open': '760.3500',
#    '2. high': '760.8000',
#    '3. low': '742.0000',
#    '4. close': '743.1500',
#    '5. volume': '454472'},
#   '2025-01-09': {'1. open': '771.9500',
#    '2. high': '771.9500',
#    '3. low': '726.9000',
#    '4. close': '760.3500',
#    '5. volume': '803943'},
#   '2025-01-08': {'1. open': '781.0000',
#    '2. high': '782.5000',
#    '3. low': '760.1000',
#    '4. close': '771.2000',
#    '5. volume': '1224097'},
#   '2025-01-07': {'1. open': '778.0500',
#    '2. high': '783.7500',
#    '3. low': '775.1000',
#    '4. close': '779.0000',
#    '5. volume': '563547'},
#   '2025-01-06': {'1. open': '798.0000',
#    '2. high': '798.0000',
#    '3. low': '773.3000',
#    '4. close': '776.7500',
#    '5. volume': '624836'},
#   '2025-01-03': {'1. open': '801.9000',
#    '2. high': '809.7000',
#    '3. low': '792.2500',
#    '4. close': '793.5000',
#    '5. volume': '387698'},
#   '2025-01-02': {'1. open': '795.0000',
#    '2. high': '802.4000',
#    '3. low': '786.3000',
#    '4. close': '801.0500',
#    '5. volume': '711599'},
#   '2025-01-01': {'1. open': '796.8500',
#    '2. high': '798.5000',
#    '3. low': '789.6000',
#    '4. close': '793.3500',
#    '5. volume': '356031'},
#   '2024-12-31': {'1. open': '788.7500',
#    '2. high': '798.9500',
#    '3. low': '787.0000',
#    '4. close': '795.0500',
#    '5. volume': '283620'},
#   '2024-12-30': {'1. open': '802.7000',
#    '2. high': '808.0000',
#    '3. low': '785.2000',
#    '4. close': '788.3000',
#    '5. volume': '686161'},
#   '2024-12-27': {'1. open': '817.2500',
#    '2. high': '818.7500',
#    '3. low': '797.2500',
#    '4. close': '799.5500',
#    '5. volume': '1061163'},
#   '2024-12-26': {'1. open': '813.0000',
#    '2. high': '822.9500',
#    '3. low': '808.0000',
#    '4. close': '811.6500',
#    '5. volume': '194920'},
#   '2024-12-24': {'1. open': '825.0000',
#    '2. high': '825.5500',
#    '3. low': '809.2000',
#    '4. close': '811.8500',
#    '5. volume': '431577'},
#   '2024-12-23': {'1. open': '818.3500',
#    '2. high': '823.9000',
#    '3. low': '812.4000',
#    '4. close': '820.9500',
#    '5. volume': '281649'},
#   '2024-12-20': {'1. open': '833.8000',
#    '2. high': '836.4000',
#    '3. low': '810.0000',
#    '4. close': '812.5000',
#    '5. volume': '467910'},
#   '2024-12-19': {'1. open': '822.0500',
#    '2. high': '837.9000',
#    '3. low': '820.1000',
#    '4. close': '832.8000',
#    '5. volume': '309033'},
#   '2024-12-18': {'1. open': '850.2000',
#    '2. high': '850.8000',
#    '3. low': '836.7000',
#    '4. close': '839.0500',
#    '5. volume': '172425'},
#   '2024-12-17': {'1. open': '859.7500',
#    '2. high': '862.9500',
#    '3. low': '847.1500',
#    '4. close': '850.2000',
#    '5. volume': '143409'},
#   '2024-12-16': {'1. open': '859.0000',
#    '2. high': '866.2000',
#    '3. low': '857.8000',
#    '4. close': '860.7000',
#    '5. volume': '252691'},
#   '2024-12-13': {'1. open': '853.7000',
#    '2. high': '863.0000',
#    '3. low': '835.0000',
#    '4. close': '861.7000',
#    '5. volume': '455324'},
#   '2024-12-12': {'1. open': '862.5000',
#    '2. high': '864.2000',
#    '3. low': '851.2500',
#    '4. close': '853.7500',
#    '5. volume': '179011'},
#   '2024-12-11': {'1. open': '865.7500',
#    '2. high': '869.7500',
#    '3. low': '860.8000',
#    '4. close': '861.5500',
#    '5. volume': '342069'},
#   '2024-12-10': {'1. open': '862.0000',
#    '2. high': '868.8500',
#    '3. low': '858.5000',
#    '4. close': '867.6000',
#    '5. volume': '197287'},
#   '2024-12-09': {'1. open': '862.9500',
#    '2. high': '866.8000',
#    '3. low': '856.7500',
#    '4. close': '857.8500',
#    '5. volume': '646144'},
#   '2024-12-06': {'1. open': '866.9500',
#    '2. high': '875.5000',
#    '3. low': '856.8500',
#    '4. close': '864.0000',
#    '5. volume': '431320'},
#   '2024-12-05': {'1. open': '861.6500',
#    '2. high': '871.0000',
#    '3. low': '855.6500',
#    '4. close': '864.8500',
#    '5. volume': '379508'},
#   '2024-12-04': {'1. open': '854.4000',
#    '2. high': '863.8000',
#    '3. low': '850.2500',
#    '4. close': '859.4500',
#    '5. volume': '679548'},
#   '2024-12-03': {'1. open': '836.4500',
#    '2. high': '856.6000',
#    '3. low': '836.4500',
#    '4. close': '853.9500',
#    '5. volume': '370485'},
#   '2024-12-02': {'1. open': '836.2000',
#    '2. high': '842.0000',
#    '3. low': '832.8000',
#    '4. close': '836.2000',
#    '5. volume': '526054'},
#   '2024-11-29': {'1. open': '842.0000',
#    '2. high': '843.8500',
#    '3. low': '831.5000',
#    '4. close': '839.0000',
#    '5. volume': '757635'},
#   '2024-11-28': {'1. open': '834.9500',
#    '2. high': '845.7000',
#    '3. low': '830.3500',
#    '4. close': '838.7500',
#    '5. volume': '811586'},
#   '2024-11-27': {'1. open': '839.3000',
#    '2. high': '842.1500',
#    '3. low': '832.0000',
#    '4. close': '834.2000',
#    '5. volume': '502957'},
#   '2024-11-26': {'1. open': '844.7500',
#    '2. high': '846.7000',
#    '3. low': '835.2000',
#    '4. close': '839.3500',
#    '5. volume': '448647'},
#   '2024-11-25': {'1. open': '826.2500',
#    '2. high': '849.3000',
#    '3. low': '825.9500',
#    '4. close': '844.7500',
#    '5. volume': '1612713'},
#   '2024-11-22': {'1. open': '785.6500',
#    '2. high': '819.7500',
#    '3. low': '784.3000',
#    '4. close': '816.0500',
#    '5. volume': '1534393'},
#   '2024-11-21': {'1. open': '800.0000',
#    '2. high': '800.0000',
#    '3. low': '761.6500',
#    '4. close': '780.8500',
#    '5. volume': '804079'},
#   '2024-11-19': {'1. open': '817.5500',
#    '2. high': '820.1000',
#    '3. low': '800.1000',
#    '4. close': '802.0000',
#    '5. volume': '467072'},
#   '2024-11-18': {'1. open': '810.0500',
#    '2. high': '816.6500',
#    '3. low': '799.2000',
#    '4. close': '813.7000',
#    '5. volume': '378989'},
#   '2024-11-14': {'1. open': '809.9500',
#    '2. high': '817.8500',
#    '3. low': '801.1000',
#    '4. close': '804.0500',
#    '5. volume': '720597'},
#   '2024-11-13': {'1. open': '822.5000',
#    '2. high': '831.6500',
#    '3. low': '804.4500',
#    '4. close': '808.3500',
#    '5. volume': '454522'},
#   '2024-11-12': {'1. open': '851.0000',
#    '2. high': '853.0000',
#    '3. low': '824.1000',
#    '4. close': '826.4000',
#    '5. volume': '467134'},
#   '2024-11-11': {'1. open': '847.0000',
#    '2. high': '853.6500',
#    '3. low': '841.4500',
#    '4. close': '847.8000',
#    '5. volume': '1417460'},
#   '2024-11-08': {'1. open': '860.0000',
#    '2. high': '863.6500',
#    '3. low': '834.3000',
#    '4. close': '843.2500',
#    '5. volume': '1106664'},
#   '2024-11-07': {'1. open': '860.0500',
#    '2. high': '862.4500',
#    '3. low': '846.7000',
#    '4. close': '859.2500',
#    '5. volume': '494821'},
#   '2024-11-06': {'1. open': '850.0000',
#    '2. high': '861.0000',
#    '3. low': '846.2000',
#    '4. close': '854.7500',
#    '5. volume': '896339'},
#   '2024-11-05': {'1. open': '829.0000',
#    '2. high': '851.2000',
#    '3. low': '826.1000',
#    '4. close': '849.2000',
#    '5. volume': '1335383'},
#   '2024-11-04': {'1. open': '822.6500',
#    '2. high': '837.5000',
#    '3. low': '807.0500',
#    '4. close': '829.8500',
#    '5. volume': '458939'},
#   '2024-10-31': {'1. open': '821.9500',
#    '2. high': '828.0000',
#    '3. low': '813.4500',
#    '4. close': '820.5000',
#    '5. volume': '497763'},
#   '2024-10-30': {'1. open': '830.0000',
#    '2. high': '832.9000',
#    '3. low': '821.0500',
#    '4. close': '822.4000',
#    '5. volume': '322347'},
#   '2024-10-29': {'1. open': '796.5000',
#    '2. high': '834.5000',
#    '3. low': '790.5000',
#    '4. close': '832.6500',
#    '5. volume': '1593501'},
#   '2024-10-28': {'1. open': '783.2000',
#    '2. high': '803.9500',
#    '3. low': '783.2000',
#    '4. close': '792.0500',
#    '5. volume': '675658'},
#   '2024-10-25': {'1. open': '798.4500',
#    '2. high': '800.0000',
#    '3. low': '772.0500',
#    '4. close': '780.6000',
#    '5. volume': '650630'},
#   '2024-10-24': {'1. open': '786.0500',
#    '2. high': '796.8000',
#    '3. low': '784.5000',
#    '4. close': '794.7000',
#    '5. volume': '183971'},
#   '2024-10-23': {'1. open': '790.0000',
#    '2. high': '792.5000',
#    '3. low': '779.6000',
#    '4. close': '785.9500',
#    '5. volume': '467975'},
#   '2024-10-22': {'1. open': '814.1500',
#    '2. high': '816.3500',
#    '3. low': '787.6000',
#    '4. close': '790.4500',
#    '5. volume': '604778'},
#   '2024-10-21': {'1. open': '822.0500',
#    '2. high': '826.3500',
#    '3. low': '809.1000',
#    '4. close': '814.1500',
#    '5. volume': '584223'},
#   '2024-10-18': {'1. open': '811.0000',
#    '2. high': '822.4000',
#    '3. low': '803.1000',
#    '4. close': '819.9500',
#    '5. volume': '429099'},
#   '2024-10-17': {'1. open': '806.0500',
#    '2. high': '819.2500',
#    '3. low': '806.0500',
#    '4. close': '810.9000',
#    '5. volume': '948591'},
#   '2024-10-16': {'1. open': '801.0500',
#    '2. high': '808.9000',
#    '3. low': '801.0500',
#    '4. close': '805.8500',
#    '5. volume': '142406'},
#   '2024-10-15': {'1. open': '805.0000',
#    '2. high': '807.6000',
#    '3. low': '801.5000',
#    '4. close': '804.6000',
#    '5. volume': '314354'},
#   '2024-10-14': {'1. open': '800.1500',
#    '2. high': '809.0000',
#    '3. low': '800.1500',
#    '4. close': '805.2500',
#    '5. volume': '755286'},
#   '2024-10-11': {'1. open': '797.0000',
#    '2. high': '802.5000',
#    '3. low': '793.0000',
#    '4. close': '800.0000',
#    '5. volume': '381115'},
#   '2024-10-10': {'1. open': '799.9000',
#    '2. high': '804.3500',
#    '3. low': '795.0500',
#    '4. close': '796.9500',
#    '5. volume': '163966'},
#   '2024-10-09': {'1. open': '787.9500',
#    '2. high': '805.0000',
#    '3. low': '782.5500',
#    '4. close': '797.0000',
#    '5. volume': '807499'},
#   '2024-10-08': {'1. open': '771.1000',
#    '2. high': '784.5000',
#    '3. low': '771.1000',
#    '4. close': '782.0500',
#    '5. volume': '295906'},
#   '2024-10-07': {'1. open': '797.0500',
#    '2. high': '803.9000',
#    '3. low': '765.5500',
#    '4. close': '769.8000',
#    '5. volume': '1587972'},
#   '2024-10-04': {'1. open': '790.3000',
#    '2. high': '809.6500',
#    '3. low': '785.2000',
#    '4. close': '796.6000',
#    '5. volume': '1154183'},
#   '2024-10-03': {'1. open': '787.4000',
#    '2. high': '803.9500',
#    '3. low': '784.3500',
#    '4. close': '794.3500',
#    '5. volume': '768391'},
#   '2024-10-01': {'1. open': '788.9500',
#    '2. high': '799.7500',
#    '3. low': '788.2500',
#    '4. close': '797.0000',
#    '5. volume': '227883'},
#   '2024-09-30': {'1. open': '801.1500',
#    '2. high': '802.5000',
#    '3. low': '786.1500',
#    '4. close': '787.6000',
#    '5. volume': '1054719'},
#   '2024-09-27': {'1. open': '802.0000',
#    '2. high': '807.8500',
#    '3. low': '798.4000',
#    '4. close': '802.6500',
#    '5. volume': '669965'}}}

# %%
data.keys()
# Out:
# dict_keys(['bestMatches'])

# %%
daily = data2["Time Series (Daily)"]
daily
# Out:
# {'2025-02-20': {'1. open': '727.8000',
#   '2. high': '731.8000',
#   '3. low': '723.0500',
#   '4. close': '729.6500',
#   '5. volume': '279931'},
#  '2025-02-19': {'1. open': '722.8000',
#   '2. high': '734.7500',
#   '3. low': '722.1000',
#   '4. close': '726.8000',
#   '5. volume': '174597'},
#  '2025-02-18': {'1. open': '727.9500',
#   '2. high': '727.9500',
#   '3. low': '717.4500',
#   '4. close': '725.7500',
#   '5. volume': '396321'},
#  '2025-02-17': {'1. open': '721.8500',
#   '2. high': '728.9500',
#   '3. low': '711.4000',
#   '4. close': '728.0500',
#   '5. volume': '751026'},
#  '2025-02-14': {'1. open': '729.4500',
#   '2. high': '732.7000',
#   '3. low': '716.1500',
#   '4. close': '722.0000',
#   '5. volume': '895669'},
#  '2025-02-13': {'1. open': '735.0000',
#   '2. high': '737.3000',
#   '3. low': '726.0500',
#   '4. close': '727.3000',
#   '5. volume': '605466'},
#  '2025-02-12': {'1. open': '732.9500',
#   '2. high': '738.3000',
#   '3. low': '717.2500',
#   '4. close': '733.2500',
#   '5. volume': '550605'},
#  '2025-02-11': {'1. open': '738.1500',
#   '2. high': '740.0000',
#   '3. low': '726.9000',
#   '4. close': '731.0000',
#   '5. volume': '826170'},
#  '2025-02-10': {'1. open': '740.5500',
#   '2. high': '744.0500',
#   '3. low': '733.6000',
#   '4. close': '736.8500',
#   '5. volume': '788061'},
#  '2025-02-07': {'1. open': '761.8000',
#   '2. high': '761.8000',
#   '3. low': '732.0500',
#   '4. close': '737.0500',
#   '5. volume': '1805880'},
#  '2025-02-06': {'1. open': '769.6500',
#   '2. high': '770.9500',
#   '3. low': '750.0000',
#   '4. close': '752.3500',
#   '5. volume': '1384322'},
#  '2025-02-05': {'1. open': '780.8000',
#   '2. high': '781.6000',
#   '3. low': '764.6500',
#   '4. close': '766.1000',
#   '5. volume': '654303'},
#  '2025-02-04': {'1. open': '766.3000',
#   '2. high': '780.8500',
#   '3. low': '766.0000',
#   '4. close': '779.2000',
#   '5. volume': '749753'},
#  '2025-02-03': {'1. open': '763.6500',
#   '2. high': '763.6500',
#   '3. low': '753.4500',
#   '4. close': '761.0000',
#   '5. volume': '427934'},
#  '2025-01-31': {'1. open': '765.0000',
#   '2. high': '777.7500',
#   '3. low': '759.3500',
#   '4. close': '773.1000',
#   '5. volume': '241965'},
#  '2025-01-30': {'1. open': '759.4000',
#   '2. high': '764.8500',
#   '3. low': '754.7000',
#   '4. close': '762.2000',
#   '5. volume': '618809'},
#  '2025-01-29': {'1. open': '752.5000',
#   '2. high': '760.2500',
#   '3. low': '749.8000',
#   '4. close': '758.7000',
#   '5. volume': '379821'},
#  '2025-01-28': {'1. open': '756.2000',
#   '2. high': '759.6000',
#   '3. low': '745.6500',
#   '4. close': '751.6500',
#   '5. volume': '794022'},
#  '2025-01-27': {'1. open': '740.0000',
#   '2. high': '755.3000',
#   '3. low': '736.0000',
#   '4. close': '749.2000',
#   '5. volume': '775011'},
#  '2025-01-24': {'1. open': '747.2000',
#   '2. high': '753.7500',
#   '3. low': '738.8500',
#   '4. close': '744.3500',
#   '5. volume': '458033'},
#  '2025-01-23': {'1. open': '751.9500',
#   '2. high': '755.8000',
#   '3. low': '743.3000',
#   '4. close': '745.9500',
#   '5. volume': '235130'},
#  '2025-01-22': {'1. open': '762.8500',
#   '2. high': '762.8500',
#   '3. low': '738.3000',
#   '4. close': '753.2500',
#   '5. volume': '237866'},
#  '2025-01-21': {'1. open': '784.9500',
#   '2. high': '785.3000',
#   '3. low': '756.2500',
#   '4. close': '759.0000',
#   '5. volume': '953600'},
#  '2025-01-20': {'1. open': '765.0500',
#   '2. high': '784.9500',
#   '3. low': '765.0500',
#   '4. close': '779.0500',
#   '5. volume': '559123'},
#  '2025-01-17': {'1. open': '766.9000',
#   '2. high': '767.8500',
#   '3. low': '759.4500',
#   '4. close': '764.1000',
#   '5. volume': '497950'},
#  '2025-01-16': {'1. open': '761.6500',
#   '2. high': '776.5500',
#   '3. low': '760.0500',
#   '4. close': '766.4000',
#   '5. volume': '511761'},
#  '2025-01-15': {'1. open': '753.7000',
#   '2. high': '758.8500',
#   '3. low': '750.3500',
#   '4. close': '754.0000',
#   '5. volume': '171791'},
#  '2025-01-14': {'1. open': '730.6000',
#   '2. high': '756.9000',
#   '3. low': '730.6000',
#   '4. close': '748.1000',
#   '5. volume': '687121'},
#  '2025-01-13': {'1. open': '742.9500',
#   '2. high': '743.8500',
#   '3. low': '722.5000',
#   '4. close': '729.6000',
#   '5. volume': '300275'},
#  '2025-01-10': {'1. open': '760.3500',
#   '2. high': '760.8000',
#   '3. low': '742.0000',
#   '4. close': '743.1500',
#   '5. volume': '454472'},
#  '2025-01-09': {'1. open': '771.9500',
#   '2. high': '771.9500',
#   '3. low': '726.9000',
#   '4. close': '760.3500',
#   '5. volume': '803943'},
#  '2025-01-08': {'1. open': '781.0000',
#   '2. high': '782.5000',
#   '3. low': '760.1000',
#   '4. close': '771.2000',
#   '5. volume': '1224097'},
#  '2025-01-07': {'1. open': '778.0500',
#   '2. high': '783.7500',
#   '3. low': '775.1000',
#   '4. close': '779.0000',
#   '5. volume': '563547'},
#  '2025-01-06': {'1. open': '798.0000',
#   '2. high': '798.0000',
#   '3. low': '773.3000',
#   '4. close': '776.7500',
#   '5. volume': '624836'},
#  '2025-01-03': {'1. open': '801.9000',
#   '2. high': '809.7000',
#   '3. low': '792.2500',
#   '4. close': '793.5000',
#   '5. volume': '387698'},
#  '2025-01-02': {'1. open': '795.0000',
#   '2. high': '802.4000',
#   '3. low': '786.3000',
#   '4. close': '801.0500',
#   '5. volume': '711599'},
#  '2025-01-01': {'1. open': '796.8500',
#   '2. high': '798.5000',
#   '3. low': '789.6000',
#   '4. close': '793.3500',
#   '5. volume': '356031'},
#  '2024-12-31': {'1. open': '788.7500',
#   '2. high': '798.9500',
#   '3. low': '787.0000',
#   '4. close': '795.0500',
#   '5. volume': '283620'},
#  '2024-12-30': {'1. open': '802.7000',
#   '2. high': '808.0000',
#   '3. low': '785.2000',
#   '4. close': '788.3000',
#   '5. volume': '686161'},
#  '2024-12-27': {'1. open': '817.2500',
#   '2. high': '818.7500',
#   '3. low': '797.2500',
#   '4. close': '799.5500',
#   '5. volume': '1061163'},
#  '2024-12-26': {'1. open': '813.0000',
#   '2. high': '822.9500',
#   '3. low': '808.0000',
#   '4. close': '811.6500',
#   '5. volume': '194920'},
#  '2024-12-24': {'1. open': '825.0000',
#   '2. high': '825.5500',
#   '3. low': '809.2000',
#   '4. close': '811.8500',
#   '5. volume': '431577'},
#  '2024-12-23': {'1. open': '818.3500',
#   '2. high': '823.9000',
#   '3. low': '812.4000',
#   '4. close': '820.9500',
#   '5. volume': '281649'},
#  '2024-12-20': {'1. open': '833.8000',
#   '2. high': '836.4000',
#   '3. low': '810.0000',
#   '4. close': '812.5000',
#   '5. volume': '467910'},
#  '2024-12-19': {'1. open': '822.0500',
#   '2. high': '837.9000',
#   '3. low': '820.1000',
#   '4. close': '832.8000',
#   '5. volume': '309033'},
#  '2024-12-18': {'1. open': '850.2000',
#   '2. high': '850.8000',
#   '3. low': '836.7000',
#   '4. close': '839.0500',
#   '5. volume': '172425'},
#  '2024-12-17': {'1. open': '859.7500',
#   '2. high': '862.9500',
#   '3. low': '847.1500',
#   '4. close': '850.2000',
#   '5. volume': '143409'},
#  '2024-12-16': {'1. open': '859.0000',
#   '2. high': '866.2000',
#   '3. low': '857.8000',
#   '4. close': '860.7000',
#   '5. volume': '252691'},
#  '2024-12-13': {'1. open': '853.7000',
#   '2. high': '863.0000',
#   '3. low': '835.0000',
#   '4. close': '861.7000',
#   '5. volume': '455324'},
#  '2024-12-12': {'1. open': '862.5000',
#   '2. high': '864.2000',
#   '3. low': '851.2500',
#   '4. close': '853.7500',
#   '5. volume': '179011'},
#  '2024-12-11': {'1. open': '865.7500',
#   '2. high': '869.7500',
#   '3. low': '860.8000',
#   '4. close': '861.5500',
#   '5. volume': '342069'},
#  '2024-12-10': {'1. open': '862.0000',
#   '2. high': '868.8500',
#   '3. low': '858.5000',
#   '4. close': '867.6000',
#   '5. volume': '197287'},
#  '2024-12-09': {'1. open': '862.9500',
#   '2. high': '866.8000',
#   '3. low': '856.7500',
#   '4. close': '857.8500',
#   '5. volume': '646144'},
#  '2024-12-06': {'1. open': '866.9500',
#   '2. high': '875.5000',
#   '3. low': '856.8500',
#   '4. close': '864.0000',
#   '5. volume': '431320'},
#  '2024-12-05': {'1. open': '861.6500',
#   '2. high': '871.0000',
#   '3. low': '855.6500',
#   '4. close': '864.8500',
#   '5. volume': '379508'},
#  '2024-12-04': {'1. open': '854.4000',
#   '2. high': '863.8000',
#   '3. low': '850.2500',
#   '4. close': '859.4500',
#   '5. volume': '679548'},
#  '2024-12-03': {'1. open': '836.4500',
#   '2. high': '856.6000',
#   '3. low': '836.4500',
#   '4. close': '853.9500',
#   '5. volume': '370485'},
#  '2024-12-02': {'1. open': '836.2000',
#   '2. high': '842.0000',
#   '3. low': '832.8000',
#   '4. close': '836.2000',
#   '5. volume': '526054'},
#  '2024-11-29': {'1. open': '842.0000',
#   '2. high': '843.8500',
#   '3. low': '831.5000',
#   '4. close': '839.0000',
#   '5. volume': '757635'},
#  '2024-11-28': {'1. open': '834.9500',
#   '2. high': '845.7000',
#   '3. low': '830.3500',
#   '4. close': '838.7500',
#   '5. volume': '811586'},
#  '2024-11-27': {'1. open': '839.3000',
#   '2. high': '842.1500',
#   '3. low': '832.0000',
#   '4. close': '834.2000',
#   '5. volume': '502957'},
#  '2024-11-26': {'1. open': '844.7500',
#   '2. high': '846.7000',
#   '3. low': '835.2000',
#   '4. close': '839.3500',
#   '5. volume': '448647'},
#  '2024-11-25': {'1. open': '826.2500',
#   '2. high': '849.3000',
#   '3. low': '825.9500',
#   '4. close': '844.7500',
#   '5. volume': '1612713'},
#  '2024-11-22': {'1. open': '785.6500',
#   '2. high': '819.7500',
#   '3. low': '784.3000',
#   '4. close': '816.0500',
#   '5. volume': '1534393'},
#  '2024-11-21': {'1. open': '800.0000',
#   '2. high': '800.0000',
#   '3. low': '761.6500',
#   '4. close': '780.8500',
#   '5. volume': '804079'},
#  '2024-11-19': {'1. open': '817.5500',
#   '2. high': '820.1000',
#   '3. low': '800.1000',
#   '4. close': '802.0000',
#   '5. volume': '467072'},
#  '2024-11-18': {'1. open': '810.0500',
#   '2. high': '816.6500',
#   '3. low': '799.2000',
#   '4. close': '813.7000',
#   '5. volume': '378989'},
#  '2024-11-14': {'1. open': '809.9500',
#   '2. high': '817.8500',
#   '3. low': '801.1000',
#   '4. close': '804.0500',
#   '5. volume': '720597'},
#  '2024-11-13': {'1. open': '822.5000',
#   '2. high': '831.6500',
#   '3. low': '804.4500',
#   '4. close': '808.3500',
#   '5. volume': '454522'},
#  '2024-11-12': {'1. open': '851.0000',
#   '2. high': '853.0000',
#   '3. low': '824.1000',
#   '4. close': '826.4000',
#   '5. volume': '467134'},
#  '2024-11-11': {'1. open': '847.0000',
#   '2. high': '853.6500',
#   '3. low': '841.4500',
#   '4. close': '847.8000',
#   '5. volume': '1417460'},
#  '2024-11-08': {'1. open': '860.0000',
#   '2. high': '863.6500',
#   '3. low': '834.3000',
#   '4. close': '843.2500',
#   '5. volume': '1106664'},
#  '2024-11-07': {'1. open': '860.0500',
#   '2. high': '862.4500',
#   '3. low': '846.7000',
#   '4. close': '859.2500',
#   '5. volume': '494821'},
#  '2024-11-06': {'1. open': '850.0000',
#   '2. high': '861.0000',
#   '3. low': '846.2000',
#   '4. close': '854.7500',
#   '5. volume': '896339'},
#  '2024-11-05': {'1. open': '829.0000',
#   '2. high': '851.2000',
#   '3. low': '826.1000',
#   '4. close': '849.2000',
#   '5. volume': '1335383'},
#  '2024-11-04': {'1. open': '822.6500',
#   '2. high': '837.5000',
#   '3. low': '807.0500',
#   '4. close': '829.8500',
#   '5. volume': '458939'},
#  '2024-10-31': {'1. open': '821.9500',
#   '2. high': '828.0000',
#   '3. low': '813.4500',
#   '4. close': '820.5000',
#   '5. volume': '497763'},
#  '2024-10-30': {'1. open': '830.0000',
#   '2. high': '832.9000',
#   '3. low': '821.0500',
#   '4. close': '822.4000',
#   '5. volume': '322347'},
#  '2024-10-29': {'1. open': '796.5000',
#   '2. high': '834.5000',
#   '3. low': '790.5000',
#   '4. close': '832.6500',
#   '5. volume': '1593501'},
#  '2024-10-28': {'1. open': '783.2000',
#   '2. high': '803.9500',
#   '3. low': '783.2000',
#   '4. close': '792.0500',
#   '5. volume': '675658'},
#  '2024-10-25': {'1. open': '798.4500',
#   '2. high': '800.0000',
#   '3. low': '772.0500',
#   '4. close': '780.6000',
#   '5. volume': '650630'},
#  '2024-10-24': {'1. open': '786.0500',
#   '2. high': '796.8000',
#   '3. low': '784.5000',
#   '4. close': '794.7000',
#   '5. volume': '183971'},
#  '2024-10-23': {'1. open': '790.0000',
#   '2. high': '792.5000',
#   '3. low': '779.6000',
#   '4. close': '785.9500',
#   '5. volume': '467975'},
#  '2024-10-22': {'1. open': '814.1500',
#   '2. high': '816.3500',
#   '3. low': '787.6000',
#   '4. close': '790.4500',
#   '5. volume': '604778'},
#  '2024-10-21': {'1. open': '822.0500',
#   '2. high': '826.3500',
#   '3. low': '809.1000',
#   '4. close': '814.1500',
#   '5. volume': '584223'},
#  '2024-10-18': {'1. open': '811.0000',
#   '2. high': '822.4000',
#   '3. low': '803.1000',
#   '4. close': '819.9500',
#   '5. volume': '429099'},
#  '2024-10-17': {'1. open': '806.0500',
#   '2. high': '819.2500',
#   '3. low': '806.0500',
#   '4. close': '810.9000',
#   '5. volume': '948591'},
#  '2024-10-16': {'1. open': '801.0500',
#   '2. high': '808.9000',
#   '3. low': '801.0500',
#   '4. close': '805.8500',
#   '5. volume': '142406'},
#  '2024-10-15': {'1. open': '805.0000',
#   '2. high': '807.6000',
#   '3. low': '801.5000',
#   '4. close': '804.6000',
#   '5. volume': '314354'},
#  '2024-10-14': {'1. open': '800.1500',
#   '2. high': '809.0000',
#   '3. low': '800.1500',
#   '4. close': '805.2500',
#   '5. volume': '755286'},
#  '2024-10-11': {'1. open': '797.0000',
#   '2. high': '802.5000',
#   '3. low': '793.0000',
#   '4. close': '800.0000',
#   '5. volume': '381115'},
#  '2024-10-10': {'1. open': '799.9000',
#   '2. high': '804.3500',
#   '3. low': '795.0500',
#   '4. close': '796.9500',
#   '5. volume': '163966'},
#  '2024-10-09': {'1. open': '787.9500',
#   '2. high': '805.0000',
#   '3. low': '782.5500',
#   '4. close': '797.0000',
#   '5. volume': '807499'},
#  '2024-10-08': {'1. open': '771.1000',
#   '2. high': '784.5000',
#   '3. low': '771.1000',
#   '4. close': '782.0500',
#   '5. volume': '295906'},
#  '2024-10-07': {'1. open': '797.0500',
#   '2. high': '803.9000',
#   '3. low': '765.5500',
#   '4. close': '769.8000',
#   '5. volume': '1587972'},
#  '2024-10-04': {'1. open': '790.3000',
#   '2. high': '809.6500',
#   '3. low': '785.2000',
#   '4. close': '796.6000',
#   '5. volume': '1154183'},
#  '2024-10-03': {'1. open': '787.4000',
#   '2. high': '803.9500',
#   '3. low': '784.3500',
#   '4. close': '794.3500',
#   '5. volume': '768391'},
#  '2024-10-01': {'1. open': '788.9500',
#   '2. high': '799.7500',
#   '3. low': '788.2500',
#   '4. close': '797.0000',
#   '5. volume': '227883'},
#  '2024-09-30': {'1. open': '801.1500',
#   '2. high': '802.5000',
#   '3. low': '786.1500',
#   '4. close': '787.6000',
#   '5. volume': '1054719'},
#  '2024-09-27': {'1. open': '802.0000',
#   '2. high': '807.8500',
#   '3. low': '798.4000',
#   '4. close': '802.6500',
#   '5. volume': '669965'}}

# %%
import pandas as pd
df = pd.DataFrame(daily).T
df
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2025-02-20  727.8000  731.8000  723.0500  729.6500    279931
# 2025-02-19  722.8000  734.7500  722.1000  726.8000    174597
# 2025-02-18  727.9500  727.9500  717.4500  725.7500    396321
# 2025-02-17  721.8500  728.9500  711.4000  728.0500    751026
# 2025-02-14  729.4500  732.7000  716.1500  722.0000    895669
# ...              ...       ...       ...       ...       ...
# 2024-10-04  790.3000  809.6500  785.2000  796.6000   1154183
# 2024-10-03  787.4000  803.9500  784.3500  794.3500    768391
# 2024-10-01  788.9500  799.7500  788.2500  797.0000    227883
# 2024-09-30  801.1500  802.5000  786.1500  787.6000   1054719
# 2024-09-27  802.0000  807.8500  798.4000  802.6500    669965
#
# [100 rows x 5 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['2025-02-20', '2025-02-19', '2025-02-18', '2025-02-17',
#                '2025-02-14', '2025-02-13', '2025-02-12', '2025-02-11',
#                '2025-02-10', '2025-02-07', '2025-02-06', '2025-02-05',
#                '2025-02-04', '2025-02-03', '2025-01-31', '2025-01-30',
#                '2025-01-29', '2025-01-28', '2025-01-27', '2025-01-24',
#                '2025-01-23', '2025-01-22', '2025-01-21', '2025-01-20',
#                '2025-01-17', '2025-01-16', '2025-01-15', '2025-01-14',
#                '2025-01-13', '2025-01-10', '2025-01-09', '2025-01-08',
#                '2025-01-07', '2025-01-06', '2025-01-03', '2025-01-02',
#                '2025-01-01', '2024-12-31', '2024-12-30', '2024-12-27',
#                '2024-12-26', '2024-12-24', '2024-12-23', '2024-12-20',
#                '2024-12-19', '2024-12-18', '2024-12-17', '2024-12-16',
#                '2024-12-13', '2024-12-12', '2024-12-11', '2024-12-10',
#                '2024-12-09', '2024-12-06', '2024-12-05', '2024-12-04',
#                '2024-12-03', '2024-12-02', '2024-11-29', '2024-11-28',
#                '2024-11-27', '2024-11-26', '2024-11-25', '2024-11-22',
#                '2024-11-21', '2024-11-19', '2024-11-18', '2024-11-14',
#                '2024-11-13', '2024-11-12', '2024-11-11', '2024-11-08',
#                '2024-11-07', '2024-11-06', '2024-11-05', '2024-11-04',
#                '2024-10-31', '2024-10-30', '2024-10-29', '2024-10-28',
#                '2024-10-25', '2024-10-24', '2024-10-23', '2024-10-22',
#                '2024-10-21', '2024-10-18', '2024-10-17', '2024-10-16',
#                '2024-10-15', '2024-10-14', '2024-10-11', '2024-10-10',
#                '2024-10-09', '2024-10-08', '2024-10-07', '2024-10-04',
#                '2024-10-03', '2024-10-01', '2024-09-30', '2024-09-27'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
df = df.astype(float)
df.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
df.head()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2025-02-20   727.80   731.80  723.05    729.65   279931.0
# 2025-02-19   722.80   734.75  722.10    726.80   174597.0
# 2025-02-18   727.95   727.95  717.45    725.75   396321.0
# 2025-02-17   721.85   728.95  711.40    728.05   751026.0
# 2025-02-14   729.45   732.70  716.15    722.00   895669.0

# %%
df.to_csv("SBIN.csv")

# %% [markdown]
# ### Plating abov chart

# %%
# %pip install plotly nbformat
# Out:
# Requirement already satisfied: plotly in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (5.24.1)
# Requirement already satisfied: nbformat in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: tenacity>=6.2.0 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: fastjsonschema>=2.15 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in p:\etlhive\python\advance python\adnace python\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(
    data = [
        go.Candlestick(
            x = df.index,
            open = df["1. open"],
            high = df["2. high"],
            low = df["3. low"],
            close = df["4. close"]
        )
    ]
)
fig.show()

# %% [markdown]
# ### Create a class to get data from any comany

# %%
class Stock:
    def __init__(self):
        self.api = os.getenv("API_KEY")
        self.url = "https://alpha-vantage.p.rapidapi.com/query"
        self.headers = {
            "x-rapidapi-key": api,
            "x-rapidapi-host": "alpha-vantage.p.rapidapi.com",
        }

    def symbol_search(self, company):
        querystring = {
            "datatype": "json",
            "keywords": company,
            "function": "SYMBOL_SEARCH",
        }
        response = requests.get(self.url, headers=self.headers, params=querystring)
        data = response.json()
        d = {}
        for i in data["bestMatches"]:
            symbol = i["1. symbol"]
            d[symbol] = i["2. name"], i["4. region"], i["8. currency"]
        return d

    def Daily_price(self, symbol):
        querystring = {
            "function": "TIME_SERIES_DAILY",
            "symbol": symbol,
            "outputsize": "compact",
            "datatype": "json",
        }
        response = requests.get(self.url, headers=self.headers, params=querystring)
        data = response.json()
        daily = data["Time Series (Daily)"]
        df = pd.DataFrame(daily).T
        df.index = pd.to_datetime(df.index)
        df = df.astype(float)
        return df
    def plot_candlestick(self, df: pd.DataFrame):
        fig = go.Figure(
        data = [
            go.Candlestick(
                x = df.index,
                open = df["1. open"],
                high = df["2. high"],
                low = df["3. low"],
                close = df["4. close"]
            )
        ]
        )
        fig.show()
        return fig

# %%
Clint = Stock()

# %%
Clint.symbol_search("Microsoft")
# Out:
# {'MSF0.FRK': ('MICROSOFT CORP. CDR', 'Frankfurt', 'EUR'),
#  'MSFT': ('Microsoft Corporation', 'United States', 'USD'),
#  '0QYP.LON': ('Microsoft Corporation', 'United Kingdom', 'USD'),
#  'MSF.DEX': ('Microsoft Corporation', 'XETRA', 'EUR'),
#  'MSF.FRK': ('Microsoft Corporation', 'Frankfurt', 'EUR'),
#  'MSFT34.SAO': ('Microsoft Corporation', 'Brazil/Sao Paolo', 'BRL'),
#  'MSFT.TRT': ('Microsoft CDR (CAD Hedged)', 'Toronto', 'CAD')}

# %%
df3 = Clint.Daily_price("MSFT")

# %%
df3
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# 2025-02-20  415.290  419.310  412.54    416.13  23508728.0
# 2025-02-19  407.880  415.490  407.65    414.77  24114197.0
# 2025-02-18  408.000  410.597  406.50    409.64  21423051.0
# 2025-02-14  407.790  408.910  405.88    408.43  22758464.0
# 2025-02-13  407.000  411.000  406.36    410.54  23891731.0
# ...             ...      ...     ...       ...         ...
# 2024-10-02  422.580  422.820  416.71    417.13  16582257.0
# 2024-10-01  428.450  428.480  418.81    420.69  19092945.0
# 2024-09-30  428.210  430.420  425.37    430.30  16854606.0
# 2024-09-27  431.520  431.850  427.47    428.02  14896131.0
# 2024-09-26  435.085  435.300  429.13    431.31  14492044.0
#
# [100 rows x 5 columns]

# %%
df3.to_csv("MSFT.csv")

# %%
Clint.plot_candlestick(df3)
